# %% [markdown]
# # Downloading Train data
#
# This file is downloading the train file from the google drive.

# %%
import gdown

# Use our existing function to build the download URL
train_url = make_drive_url(file_ids["train"])

# Download the file using gdown
gdown.download(train_url, output="data/raw/train.csv", quiet=False)
