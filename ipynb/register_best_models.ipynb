# %% [markdown]
# # Register the Best Models
# This notebook registers the weekly, monthly, and quarterly champion models in MLflow so they can be served by the forecasting app.

# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
# weekly
modle_name = "Champion_RandomForest"
model_uri = "runs:/5d91e24115344f22b56ca6b986ee3887/model"
mlflow.register_model(model_uri=model_uri, name=modle_name)
# monthly
modle_name = "Champion_XGBoost"
model_uri = "runs:/4bfd105bb2224a91827d293bd80e3356/model"
mlflow.register_model(model_uri=model_uri, name=modle_name)
# quarterly
modle_name = "Champion_Prophet"
model_uri = "runs:/30170cd697f2442082b7c31d87fd4371/model"
mlflow.register_model(model_uri=model_uri, name=modle_name)
# Out:
# Registered model 'Champion_RandomForest' already exists. Creating a new version of this model...
# 2026/05/04 10:17:12 WARNING mlflow.tracking._model_registry.fluent: Run with id 5d91e24115344f22b56ca6b986ee3887 has no artifacts at artifact path 'model', registering model based on models:/m-871f93c5ee2c4b0481de1a26ea9c0d1c instead
# 2026/05/04 10:17:12 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Champion_RandomForest, version 4
# Created version '4' of model 'Champion_RandomForest'.
# Registered model 'Champion_XGBoost' already exists. Creating a new version of this model...
# 2026/05/04 10:17:12 WARNING mlflow.tracking._model_registry.fluent: Run with id 4bfd105bb2224a91827d293bd80e3356 has no artifacts at artifact path 'model', registering model based on models:/m-deade3c01c9a4035975b7692eeddf1fb instead
# ...
